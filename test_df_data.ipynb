# %%
import numpy as np
import pandas as pd
import json 
from pandas import json_normalize

# %%
with open('/Users/ericaj/DE_PROJECTS/jobs_data_project/git_test_scarpfly/scrapfly-scrapers/glassdoor-scraper/results/jobs.json') as f:
    try:
        data = json.load(f)
        df_jobs = json_normalize(data)
        print(df_jobs.head())
    except json.JSONDecodeError as e:
        print(f"Error de decodificación JSON: {e}")
# Out:
#       __typename  adOrderId advertiserType  ageInDays divisionEmployerName  \
# 0  JobViewHeader    1136043        GENERAL         17                 None
# 1  JobViewHeader    1136043        GENERAL         17                 None
# 2  JobViewHeader    1136043        GENERAL         17                 None
# 3  JobViewHeader    1136043        GENERAL         17                 None
# 4  JobViewHeader    1136043        GENERAL         17                 None
#
#    easyApply                              goc  gocConfidence   gocId  \
# 0      False  customer service representative            0.9  102211
# 1      False  customer service representative            0.9  102211
# 2      False  customer service representative            0.9  102211
# 3      False  customer service representative            0.9  102211
# 4      False  customer service representative            0.9  102211
#
#    jobCountryId  ... payPeriod       salarySource savedJobId  \
# ...

# %%
pd.DataFrame(df_jobs)
# Out:
#         __typename  adOrderId advertiserType  ageInDays divisionEmployerName  \
# 0    JobViewHeader    1136043        GENERAL         17                 None
# 1    JobViewHeader    1136043        GENERAL         17                 None
# 2    JobViewHeader    1136043        GENERAL         17                 None
# 3    JobViewHeader    1136043        GENERAL         17                 None
# 4    JobViewHeader    1136043        GENERAL         17                 None
# ..             ...        ...            ...        ...                  ...
# 101  JobViewHeader    1136043        GENERAL         72                 None
# 102  JobViewHeader    1136043        GENERAL         14                 None
# 103  JobViewHeader    1136043        GENERAL         24                 None
# 104  JobViewHeader    1136043        GENERAL         31                 None
# 105  JobViewHeader    1136043        GENERAL        121                 None
#
# ...
